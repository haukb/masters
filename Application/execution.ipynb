# %%
from execution import run_pipeline

# %%
run_pipeline()
# Out:
# Using license file /Users/haukbjornland/gurobi.lic
# Academic license - for non-commercial use only
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# 2021-04-29 17:55:21,266	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8266
# (pid=31834) Using license file /Users/haukbjornland/gurobi.lic
# (pid=31834) Academic license - for non-commercial use only
# (pid=31836) Using license file /Users/haukbjornland/gurobi.lic
# (pid=31836) Academic license - for non-commercial use only
# (pid=31826) Using license file /Users/haukbjornland/gurobi.lic
# (pid=31826) Academic license - for non-commercial use only
# (pid=31835) Using license file /Users/haukbjornland/gurobi.lic
# (pid=31835) Academic license - for non-commercial use only
# (pid=31830) Using license file /Users/haukbjornland/gurobi.lic
# (pid=31830) Academic license - for non-commercial use only
# (pid=31829) Using license file /Users/haukbjornland/gurobi.lic
# ...
